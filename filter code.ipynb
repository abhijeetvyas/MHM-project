# %%
import numpy as np
import scipy.fftpack
import matplotlib
import matplotlib.pyplot as plt

N = 100
x = np.linspace(0,2*np.pi,N)
y = np.sin(x) + np.random.random(N) * 0.2

w = scipy.fftpack.rfft(y)
f = scipy.fftpack.rfftfreq(N, x[1]-x[0])
spectrum = w**2

cutoff_idx = spectrum < (spectrum.max()/5)
w2 = w.copy()
w2[cutoff_idx] = 0

y2 = scipy.fftpack.irfft(w2)

# %%
plt.plot(y2)

# %%
plt.plot(y)

# %%
path ='C:\Users\lenovo\Documents\acads\MHM\PROJECT\Data set N1\Data set N1\Raw_gait_data_N1 set.csv'
f = open(path, 'r')
data = f.read()
# Out:
#   File "<ipython-input-30-fbb3cbc49c8a>", line 1
#     path ='C:\Users\lenovo\Documents\acads\MHM\PROJECT\Data set N1\Data set N1\Raw_gait_data_N1 set.csv'
#          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
f
# Out:
# <_io.TextIOWrapper name='Raw_gait_data_N1 set.xls' mode='r' encoding='cp1252'>

# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd 
 
file = r'C:\Users\lenovo\Documents\acads\MHM\PROJECT\Data set N1\Data set N1\Raw_gait_data_N1 set.csv'
df = pd.read_csv(file)

# %%
df[["Right hip X", "Right hip Y"]]
# Out:
#      Right hip X  Right hip Y
# 0          44.94        78.58
# 1          47.31        78.58
# 2          49.57        78.71
# 3          51.74        79.21
# 4          53.33        79.09
# 5          55.41        79.98
# 6          56.73        80.49
# 7          58.89        81.00
# 8          60.79        81.12
# 9          62.78        82.01
# 10         64.69        82.40
# 11         66.67        82.78
# 12         68.65        82.65
# 13         70.88        83.16
# 14         73.19        82.90
# 15         74.89        83.03
# 16         76.95        82.90
# 17         79.19        82.65
# 18         81.20        82.40
# 19         83.12        82.14
# 20         85.69        81.50
# 21         87.77        80.49
# 22         89.91        80.61
# 23         92.25        80.49
# 24         94.41        80.10
# 25         97.03        79.72
# 26         99.37        79.98
# 27        101.53        79.34
# 28        104.45        79.60
# 29        106.78        79.60
# ...
