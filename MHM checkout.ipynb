# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('F:\Python Workspace\DOCUMENTS\Raw_gait_data_N1 set.csv', sep=',')

# %%
df;

# %%
t=df.loc[:,"TIME"]

# %%
metatardatax=df.loc[:,"Right metatarsal X"]

# %%
metatardatay=df.loc[:,"Right metatarsal Y"]

# %%
k=df.plot(x="TIME",y="Right metatarsal X")

# %%
import numpy as np
import scipy.fftpack
import matplotlib
import matplotlib.pyplot as plt

N = 106
x = t
y = metatardatax

w = scipy.fftpack.rfft(y)
f = scipy.fftpack.rfftfreq(N, x[1]-x[0])
spectrum = w**2

cutoff_idx = spectrum < (spectrum.max()/300000)
w2 = w.copy()
w2[cutoff_idx] = 0

y2 = scipy.fftpack.irfft(w2)

# %%
plt.plot(t,y2)

# %%
from scipy.signal import filtfilt

# %%
n = 1 # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a,y)
plt.plot(x, yy, linewidth=2, linestyle="-", c="b")

# %%
n = 10 # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = filtfilt(b,a,y)
plt.plot(x, yy, linewidth=2, linestyle="-", c="b")

# %%
def filterdata(x,y,n):
    from scipy.signal import filtfilt
    n = 10 # the larger n is, the smoother curve will be
    b = [1.0 / n] * n
    a = 1
    yy = filtfilt(b,a,y)
    plt.plot(x, yy, linewidth=2, linestyle="-", c="b")
    plt.plot(x,y,linewidth=2, linestyle="-", c="r")
    return yy;

# %%
yy=filterdata(x,y,10)

# %%
x
