# %%
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
from scipy.signal import filtfilt

# %matplotlib notebook
from matplotlib import animation
from matplotlib.animation import FuncAnimation
import numpy as np


df = pd.read_csv('Data set N1/Raw_gait_data_N1 set.csv')

time = df.loc[:,"TIME"]

ankle_x= df.loc[:,"RIGHT ANKLE X"]
ankle_y= df.loc[:,"RIGHT ANKLE Y"]

knee_x= df.loc[:,"Right knee X"]
knee_y= df.loc[:,"Right knee Y"]

hip_x= df.loc[:,"Right hip X"]
hip_y= df.loc[:,"Right hip Y"]
#k1=df.plot(x="TIME",y="RIGHT ANKLE X")
#k2=df.plot(x="TIME",y="RIGHT ANKLE Y")

n = 3# the larger n is, the smoother curve will be 
b = [1.0 / n] * n 
a = 1 

ankle_y_filt = filtfilt(b,a,ankle_y) 
ankle_x_filt = filtfilt(b,a,ankle_x) 

knee_y_filt = filtfilt(b,a,knee_y) 
knee_x_filt = filtfilt(b,a,knee_x) 

hip_y_filt = filtfilt(b,a,hip_y) 
hip_x_filt = filtfilt(b,a,hip_x) 

#new_ankle_y=plt.plot(time,ankle_y_filt, linewidth=2, linestyle="-", c="b")
#new_ankle_x=plt.plot(time,ankle_x_filt, linewidth=2, linestyle="-", c="b")
#new_knee_y=plt.plot(time,knee_y_filt, linewidth=2, linestyle="-", c="b")
#new_knee_x=plt.plot(time,knee_x_filt, linewidth=2, linestyle="-", c="b")
#new_hip_y=plt.plot(time,hip_y_filt, linewidth=2, linestyle="-", c="b")
#new_hip_x=plt.plot(time,hip_x_filt, linewidth=2, linestyle="-", c="b")

# %%
fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i/10.0))  # update the data
    return line


# Init only required for blitting to give a clean slate.
def init():
    line.set_ydata(np.ma.array(x, mask=True))
    return line

ani = animation.FuncAnimation(fig, animate, init_func=init, frames=100,
                              interval=25, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig1=plt.figure()
ax=plt.axes(xlim=(0,275),ylim=(8,60))

line1, = ax.plot(ankle_x_filt[0], ankle_y_filt[0], 'ro')
line2, = ax.plot(knee_x_filt[0], knee_y_filt[0], 'ro')
line3, = ax.plot(hip_x_filt[0], hip_y_filt[0], 'ro')

def init1():
    line1.set_data(ankle_x_filt[0], ankle_y_filt[0])
    return line1,

def init2():
    line2.set_data(knee_x_filt[0], knee_y_filt[0])
    return line2,

def animate1(i):
    x=ankle_x_filt[i]
    y=ankle_y_filt[i]
    line1.set_data(x,y)
    return line1,

def animate2(i):
    x=ankle_x_filt[i]
    y=ankle_y_filt[i]
    line2.set_data(x,y)
    return line2,

anim1 = animation.FuncAnimation(fig1, animate1, init_func=init1, frames=1000, interval=500, blit=True)
anim2 = animation.FuncAnimation(fig1, animate2, init_func=init2, frames=1000, interval=500, blit=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
new=plt.plot(ankle_x_filt,ankle_y_filt, linewidth=2, linestyle="-", c="b")

# %%
new=plt.plot(knee_x_filt,knee_y_filt, linewidth=2, linestyle="-", c="b")
