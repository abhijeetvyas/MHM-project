# %% [markdown]
# Setting up the modules

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
import limb

# %% [markdown]
# obtaining the data

# %%
gaitdata=pd.read_csv('Raw_gait_data_N1 set.csv', sep=',')

# %%
time=gaitdata.loc[:,"TIME"]

# %%
anthdat=limb.AnthroData(56.7,170)

# %%
ls=anthdat[8]/100
lt=anthdat[4]/100
lf=anthdat[12]/100
lcs=anthdat[9]/100
lct=anthdat[5]/100
lcf=anthdat[13]/100
If=anthdat[14]
Is=anthdat[10]
It=anthdat[6]
mf=anthdat[11]
ms=anthdat[7]
mt=anthdat[3]

# %%
Txp=gaitdata.loc[:,"Right metatarsal X"]
Typ=gaitdata.loc[:,"Right metatarsal Y"]
Axp=gaitdata.loc[:,"RIGHT ANKLE X"]
Ayp=gaitdata.loc[:,"RIGHT ANKLE Y"]
Kxp=gaitdata.loc[:,"Right knee X"]
Kyp=gaitdata.loc[:,"Right knee Y"]
Hxp=gaitdata.loc[:,"Right hip X"]
Hyp=gaitdata.loc[:,"Right hip Y"]

# %%
Tp=[limb.filterdata(Txp,5),limb.filterdata(Typ,4)]
plt.plot(time,Tp[0]),plt.plot(time,Txp)
plt.show()
plt.plot(time,Tp[1]),plt.plot(time,Typ)
plt.show()

# %%
Ap=[limb.filterdata(Axp,5),limb.filterdata(Ayp,4)]
plt.plot(time,Ap[0]),plt.plot(time,Axp)
plt.show()
plt.plot(time,Ap[1]),plt.plot(time,Ayp)
plt.show()

# %%
Kp=[limb.filterdata(Kxp,5),limb.filterdata(Kyp,4)]
plt.plot(time,Kp[0]),plt.plot(time,Kxp)
plt.show()
plt.plot(time,Kp[1]),plt.plot(time,Kyp)
plt.show()

# %%
Hp=[limb.filterdata(Hxp,5),limb.filterdata(Hyp,4)]
plt.plot(time,Hp[0]),plt.plot(time,Hxp)
plt.show()
plt.plot(time,Hp[1]),plt.plot(time,Hyp)
plt.show()

# %%
Body=[limb.BodyPart(lf,mf,lcf,If,Tp,Ap),limb.BodyPart(ls,ms,lcs,Is,Ap,Kp),limb.BodyPart(lt,mt,lct,It,Kp,Hp)]
limb.BodyPart.time=time

# %%
GRFdata=pd.read_csv('Force plate data_N1 set.csv',sep=',')

# %%
Rx=GRFdata.loc[:,"RX"]
Ry=GRFdata.loc[:,"RY"]

# %%
Rx=limb.filterdata(Rx,2)
Ry=limb.filterdata(Ry,2)

# %% [markdown]
# The Inverse dynamics analysis is done by segmenting the body into foot, shank, thigh and the upper body is considered to be a lumped mass at the centre of mass of the upper body

# %% [markdown]
# *add the fbd of the whole body*

# %% [markdown]
# consider the foot

# %% [markdown]
# *add the fbd of the foot*

# %% [markdown]
# The kinetic diagram of the foot is as shown

# %% [markdown]
# *add kinetic diagram of the foot*

# %% [markdown]
# *add the equations here*

# %%
F=[Rx,Ry]
T=np.zeros(106)
R=[[np.zeros(106),np.zeros(106)],[np.zeros(106),np.zeros(106)],[np.zeros(106),np.zeros(106)]]
M=[np.zeros(106),np.zeros(106),np.zeros(106),np.zeros(106)]
for i in range(0,3):
    F,T=Body[i].Forces(F,T)
    R[i]=F
    M[i]=T

# %%
plt.plot(time,R[0][1])

# %% [markdown]
# Consider the shank

# %% [markdown]
# *add FBD of shank*

# %% [markdown]
# *add kinetic diagram*

# %% [markdown]
# consider the thigh

# %% [markdown]
# *add FBD of thigh*

# %% [markdown]
# *add kinetic diagram*

# %%
#filter the Joint forces and moments
#find the joint angles and joint omegas.

# %%
Power=[np.zeros(106),np.zeros(106),np.zeros(106)]

# %%
Power[0]=limb.Power(Body[0].omega,Body[1].omega,M[0])
Power[1]=limb.Power(Body[1].omega,Body[2].omega,M[1])
Power[2]=limb.Power(Body[2].omega,np.zeros(106),M[2])

# %%
for i in range(0,3):
    Power[i]=limb.filterdata(Power[i],3)

# %%
plt.plot(time,Power[0]),plt.plot(time,Power[1]),plt.plot(time,Power[2])
# Out:
# ([<matplotlib.lines.Line2D at 0x95792d780>],
#  [<matplotlib.lines.Line2D at 0x9578f9c88>],
#  [<matplotlib.lines.Line2D at 0x95792dd30>])

# %%
F=limb.aCoM(Body[0].mass,Body[0].accelCoM,Body[1].mass,Body[1].accelCoM,Body[2].mass,Body[2].accelCoM,56.7-Body[0].mass-Body[1].mass-Body[2].mass,Body[2].accelProxim)

# %%
plt.plot(time,F[1]),plt.plot(time,Ry)
# Out:
# ([<matplotlib.lines.Line2D at 0x957993828>],
#  [<matplotlib.lines.Line2D at 0x957993d68>])
